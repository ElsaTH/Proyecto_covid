# %%
import pandas as pd
import numpy as pd
import matplotlib
import requests
import json
import matplotlib.pyplot as plt

from matplotlib.backends.backend_pdf import PdfPages                # @Elsa TH

# %%
url="http://192.168.0.185:6060/get/df?tok=D9748859183511168646350"

# %%
covid = requests.get(url)
j = covid.json()

df = pd.DataFrame.from_dict(j)

# %%
df.reset_index(inplace=True)
df

# %%
df.plot()  #Gráfica simple del grupo D

# %%
#df.plot(kind="line")  # Está sin poder terminar bien
plt.plot(df.index, color='green', linewidth=2, label='t_d_averages')
plt.title("COVID 19")
plt.xticks(rotation=90)
xticks = [y for y in range(df.index.min(), df.index.max(), 1)]
plt.xlabel('Year')

plt.show()
